# %%
import requests
url = "https://rest.soilgrids.org/query?lon=5.39&lat=51.57"
response = requests.get(url)

# %%
response.json()
# Out:
# {u'crs': {u'properties': {u'name': u'urn:ogc:def:crs:OGC:1.3:CRS84'},
#   u'type': u'name'},
#  u'geometry': {u'coordinates': [5.39, 51.57], u'type': u'Point'},
#  u'properties': {u'ALUM3S': {u'M': {u'xd1': None, u'xd2': None},
#    u'units_of_measure': u'ppm'},
#   u'AWCh1': {u'M': {u'sl1': 19,
#     u'sl2': 20,
#     u'sl3': 18,
#     u'sl4': 17,
#     u'sl5': 14,
#     u'sl6': 14,
#     u'sl7': 15},
#    u'units_of_measure': u'percent'},
#   u'AWCh2': {u'M': {u'sl1': 13,
#     u'sl2': 14,
#     u'sl3': 12,
#     u'sl4': 12,
#     u'sl5': 10,
#     u'sl6': 10,
#     u'sl7': 10},
#    u'units_of_measure': u'percent'},
#   u'AWCh3': {u'M': {u'sl1': 10,
#     u'sl2': 10,
#     u'sl3': 10,
#     u'sl4': 9,
#     u'sl5': 8,
#     u'sl6': 8,
#     u'sl7': 8},
#    u'units_of_measure': u'percent'},
#   u'AWCtS': {u'M': {u'sl1': 51,
#     u'sl2': 50,
#     u'sl3': 46,
#     u'sl4': 45,
#     u'sl5': 40,
#     u'sl6': 39,
#     u'sl7': 39},
#    u'units_of_measure': u'percent'},
# ...
